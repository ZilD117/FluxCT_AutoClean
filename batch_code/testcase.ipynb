# %%
import time 
import pandas as pd  
from lightkurve import search_targetpixelfile
from astropy.wcs import WCS
import matplotlib.pyplot as plt
from astropy.io import fits 
import numpy as np
from astroquery.gaia import Gaia
from astropy.coordinates import SkyCoord
import astropy.units as u
import math
from ast import literal_eval
import ssl
import lightkurve

# %%
kic = 3430893
tpf = search_targetpixelfile('KIC ' + str(kic), author='Kepler', cadence='short').download()
tpf.plot()
# Out:
# <Axes: title={'center': 'Target ID: 3430893, Cadence: 77440'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
tpf = search_targetpixelfile('TIC ' + str(kic), author='SPOC', cadence='short').download()
print(tpf==None)
# Out:
# No data found for target "TIC 3430893".
# True
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\lightkurve\search.py:418: LightkurveWarning: Cannot download from an empty search result.
#   warnings.warn(

# %%
tpf2 = lightkurve.search_tesscut("TIC 25063215").download()
tpf2.plot()
# Out:
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\lightkurve\search.py:423: LightkurveWarning: Warning: 33 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   warnings.warn(
# <Axes: title={'center': 'Target ID: TIC 25063215, Cadence: 0'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
# %matplotlib inline
tpf2.plot(frame=0)
# Out:
# <Axes: title={'center': 'Target ID: TIC 25063215, Cadence: 0'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
search_result = lightkurve.search_lightcurve('TIC 3733346', author='SPOC')
# Out:
# No data found for target "TIC 3733346".

# %%
a = "TIC 3733346"
a[4:]
# Out:
# '3733346'

# %%
import shutil
